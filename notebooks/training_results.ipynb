# %%
import matplotlib.pyplot as plt_hscnn
import matplotlib.pyplot as plt_sr_unet
import matplotlib.pyplot as plt_sr_awan
import matplotlib.pyplot as plt_sr_bfwu
import matplotlib.pyplot as plt_c_gan

# %%
epochs_hscnn = list(range(1, 51))
losses_hscnn = [
    0.03900, 0.01468, 0.01252, 0.01178, 0.01161, 0.01148, 0.01086, 0.01124, 0.01084, 0.01071,
    0.01070, 0.01051, 0.01057, 0.01050, 0.01044, 0.01071, 0.01029, 0.01025, 0.00997, 0.01030,
    0.01026, 0.01005, 0.01010, 0.01009, 0.01018, 0.00984, 0.01031, 0.00993, 0.00971, 0.00992,
    0.00958, 0.00999, 0.00975, 0.00964, 0.00959, 0.00968, 0.00961, 0.00976, 0.00938, 0.00920,
    0.00924, 0.00973, 0.00912, 0.00937, 0.00914, 0.00914, 0.00910, 0.00909, 0.00922, 0.00903
]

plt_hscnn.figure(figsize=(10, 6))
plt_hscnn.plot(epochs_hscnn, losses_hscnn, marker='o')
plt_hscnn.title('HSCNN-D (Loss by Epoch)')
plt_hscnn.xlabel('Epoch')
plt_hscnn.ylabel('Loss')
plt_hscnn.grid(True)
plt_hscnn.tight_layout()
plt_hscnn.show()

# %%
epochs_sr_unet = list(range(1, 51))
losses_sr_unet = [
    0.03162, 0.01355, 0.01322, 0.01186, 0.01152, 0.01096, 0.01080, 0.01068, 0.01003, 0.01009,
    0.00991, 0.00961, 0.00961, 0.00960, 0.00927, 0.00902, 0.00921, 0.00895, 0.00934, 0.00922,
    0.00885, 0.00876, 0.00852, 0.00910, 0.00859, 0.00861, 0.00870, 0.00836, 0.00844, 0.00864,
    0.00814, 0.00810, 0.00807, 0.00820, 0.00811, 0.00812, 0.00788, 0.00797, 0.00797, 0.00802,
    0.00782, 0.00798, 0.00762, 0.00774, 0.00762, 0.00757, 0.00765, 0.00792, 0.00756, 0.00745
]

plt_sr_unet.figure(figsize=(10, 6))
plt_sr_unet.plot(epochs_sr_unet, losses_sr_unet, marker='o')
plt_sr_unet.title('SR-UNET (Loss by Epoch)')
plt_sr_unet.xlabel('Epoch')
plt_sr_unet.ylabel('Loss')
plt_sr_unet.grid(True)
plt_sr_unet.tight_layout()
plt_sr_unet.show()

# %%
epochs_sr_awan = list(range(1, 51))
losses_sr_awan = [
    0.04169, 0.01709, 0.01537, 0.01557, 0.01528, 0.01464, 0.01293, 0.01381, 0.01331, 0.01297,
    0.01265, 0.01255, 0.01182, 0.01183, 0.01133, 0.01159, 0.01082, 0.01151, 0.01153, 0.01196,
    0.01138, 0.01178, 0.01109, 0.01072, 0.01126, 0.01101, 0.01031, 0.01028, 0.00987, 0.00990,
    0.01067, 0.01029, 0.00959, 0.01001, 0.00947, 0.01005, 0.00932, 0.00891, 0.00853, 0.00947,
    0.00890, 0.00857, 0.00861, 0.00859, 0.00814, 0.00780, 0.00840, 0.00783, 0.00738, 0.00772
]

plt_sr_awan.figure(figsize=(10, 6))
plt_sr_awan.plot(epochs_sr_awan, losses_sr_awan, marker='o')
plt_sr_awan.title('SR-AWAN (Loss by Epoch)')
plt_sr_awan.xlabel('Epoch')
plt_sr_awan.ylabel('Loss')
plt_sr_awan.grid(True)
plt_sr_awan.tight_layout()
plt_sr_awan.show()

# %%
epochs_sr_bfwu = list(range(1, 51))
